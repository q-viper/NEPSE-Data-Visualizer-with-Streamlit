# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("data/NEPSE131.csv")
# df = df.iloc[:1000]

# %%
cl="S.N., Contract No, Stock Symbol, Buyer Broker, Seller Broker, Quantity, Rate, Amount, Date"
ncl = cl.split(", ")

# %%
ndf = df.rename(columns={df.columns[i]:ncl[i] for i in range(len(ncl))})
ndf
# Out:
#        S.N.       Contract No Stock Symbol  Buyer Broker  Seller Broker  \
# 0         2            126539        NABIL             1              5
# 1         3            126455        NABIL            28             28
# 2         4            126454        NABIL            28             28
# 3         5            126376        NABIL             3             20
# 4         6            126368        NABIL           103             25
# ...     ...               ...          ...           ...            ...
# 95138  4292  2019010101000426        NABIL            46             38
# 95139  4293  2019010101000364        NABIL            42              3
# 95140  4294  2019010101000274        NABIL            45              3
# 95141  4295  2019010101000160        NABIL             1              3
# 95142  4296  2019010101000159        NABIL            45              3
#
#        Quantity  Rate     Amount                        Date
# ...

# %%
nndf = ndf.copy()[20000:30000]
nndf["Date"] = pd.to_datetime(ndf["Date"])
nndf.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\arrays\datetimes.py in objects_to_datetime64ns(data, dayfirst, yearfirst, utc, errors, require_iso8601, allow_object)
#    1978         try:
# -> 1979             values, tz_parsed = conversion.datetime_to_datetime64(data)
#    1980             # If tzaware, these values represent unix timestamps, so we
#
# pandas\_libs\tslibs\conversion.pyx in pandas._libs.tslibs.conversion.datetime_to_datetime64()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-fddd6048cd43> in <module>
#       1 nndf = ndf.copy()[20000:30000]
# ----> 2 nndf["Date"] = pd.to_datetime(ndf["Date"])
#       3 nndf.head()
#
# ...

# %%
arr = np.array(ndf.Date.tolist())
truth_value = [len(a)>15 for a in arr]
ind = truth_value.index(True)
sndf=ndf.iloc[ind:]
sndf["Date"] = pd.to_datetime(sndf["Date"])

# %%
sndf
# Out:
#        S.N.       Contract No Stock Symbol  Buyer Broker  Seller Broker  \
# 10636     1   200812310233709        NABIL            20             21
# 10637     2   200812310233683        NABIL            11             17
# 10638     3   200812310233224        NABIL            26             17
# 10639     4   200812310233155        NABIL            18             17
# 10640     5   200812310233058        NABIL            19             22
# ...     ...               ...          ...           ...            ...
# 95138  4292  2019010101000426        NABIL            46             38
# 95139  4293  2019010101000364        NABIL            42              3
# 95140  4294  2019010101000274        NABIL            45              3
# 95141  4295  2019010101000160        NABIL             1              3
# 95142  4296  2019010101000159        NABIL            45              3
#
#        Quantity  Rate    Amount                       Date
# ...
